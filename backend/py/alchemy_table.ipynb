# %%
from game.splendor_env import SplendorEnv

env = SplendorEnv()
# Out:
# [(5,), (5,), (1,), (1,), (1,), (3, 5), (3, 5), (3,), (3,), (3,), (12,), (60,), (12,), (25,), (5,), (1,)]
# [(5,), (1,), (5, 5), (3, 5), (3,), (3,), (3,), (3, 5), (5,), (1,), (1,), (1,), (5,), (12, 5), (12,), (12,)]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from game.splendor_env import SplendorEnv
# ----> 3 env = SplendorEnv()
#
# File c:\Users\duterte\Documents\DONT_FORGET_YOURE_HERE_FOREVER\splendor-ai\backend\py\game\splendor_env.py:110, in SplendorEnv.__init__(self, render_mode)
#      98 self.action_space = spaces.Discrete(
#      99     1  # get_gold
#     100     + len(self.GEM_TYPES)  # get gem pair
#    (...)    105     + 1  # pass a turn :)
#     106 )
#     108 self.render_mode = render_mode
# --> 110 self.reset()
#
# File c:\Users\duterte\Documents\DONT_FORGET_YOURE_HERE_FOREVER\splendor-ai\backend\py\game\splendor_env.py:141, in SplendorEnv.reset(self, seed, options)
#     138 print([field.shape for field in observation.values()])
#     139 print([field.shape for field in self.observation_space.values()])
# --> 141 assert self.observation_space.contains(observation)
#     143 return observation
#
# AssertionError:

# %%
import numpy as np

np.array(
    [g for noble in env.state["nobles"] for g in noble['cost'].values()], dtype=np.int32
)

# %%
card = env.cards[0]

from pprint import pprint

pprint(card)
