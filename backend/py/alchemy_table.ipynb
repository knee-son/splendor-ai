# %%
from game.splendor_env import SplendorEnv

env = SplendorEnv()

# %%
bank = env.state["bank"]
gem_types = env.GEM_TYPES

gem_types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 bank = env.state["bank"]
#       2 gem_types = env.GEM_TYPES
#       4 gem_types
#
# AttributeError: type object 'SplendorEnv' has no attribute 'state'
