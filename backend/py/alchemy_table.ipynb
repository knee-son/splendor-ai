# %%
from game.splendor_env import SplendorEnv

env = SplendorEnv()
# Out:
# 5

# %%
import numpy as np

np.array(
    [g for noble in env.state["nobles"] for g in noble['cost'].values()], dtype=np.int32
)
# Out:
# array([0, 0, 3, 3, 3, 3, 3, 3, 0, 0, 0, 3, 3, 3, 0, 3, 0, 0, 3, 3, 0, 4,
#        4, 0, 0], dtype=int32)

# %%
card = env.cards[0]

from pprint import pprint

pprint(card)
# Out:
# {'cost': {'diamond': 0, 'emerald': 0, 'onyx': 2, 'ruby': 2, 'sapphire': 1},
#  'engine': 'emerald',
#  'id': 41,
#  'prestige': 0,
#  'tier': 1}
