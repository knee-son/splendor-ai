# %%
from utils.downscale_images import downscale

downscale()
# Out:
# ✔️  backside_card.png downscaled by 0.29296875
# ✔️  backside_noble.jpg downscaled by 0.439453125
# ✔️  diamond_cafe.jpg downscaled by 0.439453125
# ✔️  diamond_gem.png downscaled by 0.048828125
# ✔️  diamond_mine.png downscaled by 0.29296875
# ✔️  diamond_prospector.png downscaled by 0.29296875
# ✔️  emerald_cafe.jpg downscaled by 0.439453125
# ✔️  emerald_gem.png downscaled by 0.048828125
# ✔️  emerald_mine.png downscaled by 0.29296875
# ✔️  emerald_prospector.png downscaled by 0.29296875
# ✔️  gold_lump.png downscaled by 0.048828125
# ✔️  noble_isabella.png downscaled by 0.29296875
# ✔️  noble_joan.png downscaled by 0.29296875
# ✔️  noble_korina.png downscaled by 0.29296875
# ✔️  noble_legaspi.png downscaled by 0.29296875
# ✔️  noble_magellan.png downscaled by 0.29296875
# ✔️  noble_pastor.png downscaled by 0.29296875
# ✔️  noble_peter.png downscaled by 0.29296875
# ✔️  noble_sultan.png downscaled by 0.29296875
# ✔️  noble_teresa.png downscaled by 0.29296875
# ...
